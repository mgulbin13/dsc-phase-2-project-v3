# %%
import sqlite3
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

conn = sqlite3.connect('zippedData/im.db')

# %%
tmdb_df = pd.read_csv('zippedData/tmdb.movies.csv')
budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv')
bom_df = pd.read_csv('zippedData/bom.movie_gross.csv')

# %%
# %%bash
# sqlite3 zippedData/im.db
# .tables
# Out:
# directors           movie_basics        principals          us_movies_df_sql
# known_for           movie_ratings       tn_movie_sql        us_movies_filt_sql
# movie_akas          persons             tn_sql              writers

# %%
# Remove dollar signs & commas, then convert to int
for col in ['production_budget', 'domestic_gross', 'worldwide_gross']:
    budgets_df[col] = budgets_df[col].replace('[\$,]', '', regex=True).astype(float).fillna(0).astype(int)

print("✅ Converted budget & revenue columns to integers!")
# Out:
# ✅ Converted budget & revenue columns to integers!
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/m7/tzk7gpbd05j79z_hsb25z6jm0000gn/T/ipykernel_1621/3426389066.py:3: SyntaxWarning: invalid escape sequence '\$'
#   budgets_df[col] = budgets_df[col].replace('[\$,]', '', regex=True).astype(float).fillna(0).astype(int)

# %%
# Remove commas and convert to numeric, replace NaNs with 0
bom_df['foreign_gross'] = bom_df['foreign_gross'].replace(',', '', regex=True).astype(float).fillna(0)

print("✅ Converted foreign_gross to a numeric type!")
# Out:
# ✅ Converted foreign_gross to a numeric type!

# %%
# Convert release_date to datetime format
tmdb_df['release_date'] = pd.to_datetime(tmdb_df['release_date'], errors='coerce')
budgets_df['release_date'] = pd.to_datetime(budgets_df['release_date'], errors='coerce')

print("✅ Converted release_date to datetime format!")
# Out:
# ✅ Converted release_date to datetime format!

# %%
# Rename 'movie' in budgets_df to 'title' to match tmdb_df and bom_df
budgets_df.rename(columns={'movie': 'title'}, inplace=True)

print("✅ Renamed 'movie' to 'title' in budgets_df!")
# Out:
# ✅ Renamed 'movie' to 'title' in budgets_df!

# %%
# Merge budget data into tmdb_df using 'id'
movies_budget_df = tmdb_df.merge(budgets_df, on='id', how='left')

print(f"✅ Merged TMDB and Budget data! New shape: {movies_budget_df.shape}")
# Out:
# ✅ Merged TMDB and Budget data! New shape: (26855, 15)

# %%
# Keep only one release_date and title column
movies_budget_df.rename(columns={'release_date_x': 'release_date', 'title_x': 'title'}, inplace=True)

# Drop the extra columns
movies_budget_df.drop(columns=['release_date_y', 'title_y'], inplace=True, errors='ignore')

print("✅ Cleaned up duplicate columns!")
# Out:
# ✅ Cleaned up duplicate columns!

# %%
movies_budget_df['year'] = movies_budget_df['release_date'].dt.year

print("✅ Extracted year from release_date!")
# Out:
# ✅ Extracted year from release_date!

# %%
# Merge BOM data into movies_budget_df
final_movies_df = movies_budget_df.merge(bom_df, on=['title', 'year'], how='left')

print(f"✅ Final dataset shape after merging BOM data: {final_movies_df.shape}")
# Out:
# ✅ Final dataset shape after merging BOM data: (26855, 17)

# %%
matched_budgets = movies_budget_df['production_budget'].notna().sum()
total_movies = len(movies_budget_df)

print(f"✅ Movies with matched budget data: {matched_budgets} / {total_movies}")
# Out:
# ✅ Movies with matched budget data: 344 / 26855

# %%
# Rename 'movie' to 'title' in budgets_df
budgets_df.rename(columns={'movie': 'title'}, inplace=True)

# Extract release year from release_date
budgets_df['year'] = budgets_df['release_date'].dt.year

print("✅ Updated budgets_df for title-based merging!")
# Out:
# ✅ Updated budgets_df for title-based merging!

# %%
# Extract year from release_date in tmdb_df
tmdb_df['year'] = pd.to_datetime(tmdb_df['release_date'], errors='coerce').dt.year

print("✅ Extracted year from release_date in tmdb_df!")
# Out:
# ✅ Extracted year from release_date in tmdb_df!

# %%
# Now merge using title and year
movies_budget_df = tmdb_df.merge(budgets_df, on=['title', 'year'], how='left')

print(f"✅ New merge complete! Movies with budget data: {movies_budget_df['production_budget'].notna().sum()} / {len(movies_budget_df)}")
# Out:
# ✅ New merge complete! Movies with budget data: 1758 / 26517

# %%
missing_budgets = movies_budget_df['production_budget'].isna().sum()
print(f"🔍 Movies still missing budget data: {missing_budgets} / {len(movies_budget_df)}")
# Out:
# 🔍 Movies still missing budget data: 24759 / 26517

# %%
# Check if 'original_title' and 'title' are identical
same_titles = (tmdb_df['original_title'] == tmdb_df['title']).sum()
total_rows = len(tmdb_df)

print(f"Identical titles: {same_titles} / {total_rows}")
# Out:
# Identical titles: 23973 / 26517

# %%
# Filter rows where original_title and title are different
different_titles = tmdb_df[tmdb_df['original_title'] != tmdb_df['title']][['original_title', 'title']]

# Show a sample of 20 different titles
print(different_titles.head(20))
# Out:
#                                       original_title  \
# 14                                            Saw 3D
# 49                        Tres metros sobre el cielo
# 67               Arthur 3: la guerre des deux mondes
# 70                            El secreto de sus ojos
# 75                                           サマーウォーズ
# 79                         Luftslottet som sprängdes
# 84                                              ゲド戦記
# 87                       Flickan som lekte med elden
# 98   Les Aventures extraordinaires d'Adèle Blanc-Sec
# 103                                                乱
# 110                          Banlieue 13 - Ultimatum
# 122                                               葉問
# 167                              Konferenz der Tiere
# 169                                      L'arnacoeur
# 171                                 Benvenuti al sud
# 188                               Брестская крепость
# 191                                       Titanic II
# 193                                       L'Immortel
# 195                               Habitación en Roma
# 198                                           冷たい熱帯魚
#
#                                                title
# 14                            Saw: The Final Chapter
# 49                          Three Steps Above Heaven
# 67               Arthur 3: The War of the Two Worlds
# 70                          The Secret in Their Eyes
# 75                                       Summer Wars
# 79             The Girl Who Kicked the Hornet's Nest
# 84                               Tales from Earthsea
# 87                     The Girl Who Played with Fire
# 98   The Extraordinary Adventures of Adèle Blanc-Sec
# 103                                              Ran
# 110                           District 13: Ultimatum
# 122                                           Ip Man
# 167                                   Animals United
# 169                                     Heartbreaker
# 171                             Welcome to the South
# 188                                  Fortress of War
# 191                                        Titanic 2
# 193                                       22 Bullets
# 195                                     Room in Rome
# 198                                        Cold Fish

# %%
tmdb_df.drop(columns=['original_title'], inplace=True)

# %%
tmdb_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  popularity  \
# 0               0      [12, 14, 10751]   12444                en      33.533
# 1               1  [14, 12, 16, 10751]   10191                en      28.734
# 2               2        [12, 28, 878]   10138                en      28.515
# 3               3      [16, 35, 10751]     862                en      28.005
# 4               4        [28, 878, 12]   27205                en      27.920
# ...           ...                  ...     ...               ...         ...
# 26512       26512             [27, 18]  488143                en       0.600
# 26513       26513             [18, 53]  485975                en       0.600
# 26514       26514         [14, 28, 12]  381231                en       0.600
# 26515       26515      [10751, 12, 28]  366854                en       0.600
# 26516       26516             [53, 27]  309885                en       0.600
#
#       release_date                                         title  \
# 0       2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1       2010-03-26                      How to Train Your Dragon
# 2       2010-05-07                                    Iron Man 2
# 3       1995-11-22                                     Toy Story
# 4       2010-07-16                                     Inception
# ...            ...                                           ...
# 26512   2018-10-13                         Laboratory Conditions
# 26513   2018-05-01                               _EXHIBIT_84xxx_
# 26514   2018-10-01                                  The Last One
# 26515   2018-06-22                                  Trailer Made
# 26516   2018-10-05                                    The Church
#
#        vote_average  vote_count  year
# 0               7.7       10788  2010
# 1               7.7        7610  2010
# 2               6.8       12368  2010
# 3               7.9       10174  1995
# 4               8.3       22186  2010
# ...             ...         ...   ...
# 26512           0.0           1  2018
# 26513           0.0           1  2018
# 26514           0.0           1  2018
# 26515           0.0           1  2018
# 26516           0.0           1  2018
#
# [26517 rows x 10 columns]

# %%
budgets_df.drop(columns=['domestic_gross'], inplace=True)
budgets_df
# Out:
#       id release_date                                        title  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#       production_budget  worldwide_gross  year
# 0             425000000       2776345279  2009
# 1             410600000       1045663875  2011
# 2             350000000        149762350  2019
# 3             330600000       1403013963  2015
# 4             317000000       1316721747  2017
# ...                 ...              ...   ...
# 5777               7000                0  2018
# 5778               6000           240495  1999
# 5779               5000             1338  2005
# 5780               1400                0  2015
# 5781               1100           181041  2005
#
# [5782 rows x 6 columns]

# %%
budgets_df = budgets_df[budgets_df['year'] >= 2000]

# %%
budgets_df['year'] = budgets_df['year'].astype(str)
# Out:
# /var/folders/m7/tzk7gpbd05j79z_hsb25z6jm0000gn/T/ipykernel_1621/2571313135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   budgets_df['year'] = budgets_df['year'].astype(str)

# %%
budgets_df['title_year'] = budgets_df['title'] + ', ' + budgets_df['year']

# %%
budgets_df = budgets_df.set_index('title_year')
budgets_df
# Out:
#                                                    id release_date  \
# title_year
# Avatar, 2009                                        1   2009-12-18
# Pirates of the Caribbean: On Stranger Tides, 2011   2   2011-05-20
# Dark Phoenix, 2019                                  3   2019-06-07
# Avengers: Age of Ultron, 2015                       4   2015-05-01
# Star Wars Ep. VIII: The Last Jedi, 2017             5   2017-12-15
# ...                                                ..          ...
# The Mongol King, 2004                              77   2004-12-31
# Red 11, 2018                                       78   2018-12-31
# Return to the Land of Wonders, 2005                80   2005-07-13
# A Plague So Pleasant, 2015                         81   2015-09-29
# My Date With Drew, 2005                            82   2005-08-05
#
#                                                                                          title  \
# title_year
# Avatar, 2009                                                                            Avatar
# Pirates of the Caribbean: On Stranger Tides, 2011  Pirates of the Caribbean: On Stranger Tides
# Dark Phoenix, 2019                                                                Dark Phoenix
# Avengers: Age of Ultron, 2015                                          Avengers: Age of Ultron
# Star Wars Ep. VIII: The Last Jedi, 2017                      Star Wars Ep. VIII: The Last Jedi
# ...                                                                                        ...
# The Mongol King, 2004                                                          The Mongol King
# Red 11, 2018                                                                            Red 11
# Return to the Land of Wonders, 2005                              Return to the Land of Wonders
# A Plague So Pleasant, 2015                                                A Plague So Pleasant
# My Date With Drew, 2005                                                      My Date With Drew
#
#                                                    production_budget  \
# title_year
# Avatar, 2009                                               425000000
# Pirates of the Caribbean: On Stranger Tides, 2011          410600000
# Dark Phoenix, 2019                                         350000000
# Avengers: Age of Ultron, 2015                              330600000
# Star Wars Ep. VIII: The Last Jedi, 2017                    317000000
# ...                                                              ...
# The Mongol King, 2004                                           7000
# Red 11, 2018                                                    7000
# Return to the Land of Wonders, 2005                             5000
# A Plague So Pleasant, 2015                                      1400
# My Date With Drew, 2005                                         1100
#
#                                                    worldwide_gross  year  \
# title_year
# Avatar, 2009                                            2776345279  2009
# Pirates of the Caribbean: On Stranger Tides, 2011       1045663875  2011
# Dark Phoenix, 2019                                       149762350  2019
# Avengers: Age of Ultron, 2015                           1403013963  2015
# Star Wars Ep. VIII: The Last Jedi, 2017                 1316721747  2017
# ...                                                            ...   ...
# The Mongol King, 2004                                          900  2004
# Red 11, 2018                                                     0  2018
# Return to the Land of Wonders, 2005                           1338  2005
# A Plague So Pleasant, 2015                                       0  2015
# My Date With Drew, 2005                                     181041  2005
#
#                                                    gross_budget_ratio
# title_year
# Avatar, 2009                                                 6.532577
# Pirates of the Caribbean: On Stranger Tides, 2011            2.546673
# Dark Phoenix, 2019                                           0.427892
# Avengers: Age of Ultron, 2015                                4.243841
# Star Wars Ep. VIII: The Last Jedi, 2017                      4.153696
# ...                                                               ...
# The Mongol King, 2004                                        0.128571
# Red 11, 2018                                                 0.000000
# Return to the Land of Wonders, 2005                          0.267600
# A Plague So Pleasant, 2015                                   0.000000
# My Date With Drew, 2005                                    164.582727
#
# [4387 rows x 7 columns]

# %%
budgets_df = budgets_df[budgets_df['production_budget']<=20000000]
budgets_df
# Out:
#                                      id release_date  \
# title_year
# Us, 2019                             88   2019-03-22
# La La Land, 2016                     92   2016-12-09
# The Conjuring, 2013                  93   2013-07-19
# Bringing Down the House, 2003        94   2003-03-07
# Wonder, 2017                         95   2017-11-17
# ...                                  ..          ...
# The Mongol King, 2004                77   2004-12-31
# Red 11, 2018                         78   2018-12-31
# Return to the Land of Wonders, 2005  80   2005-07-13
# A Plague So Pleasant, 2015           81   2015-09-29
# My Date With Drew, 2005              82   2005-08-05
#
#                                                              title  \
# title_year
# Us, 2019                                                        Us
# La La Land, 2016                                        La La Land
# The Conjuring, 2013                                  The Conjuring
# Bringing Down the House, 2003              Bringing Down the House
# Wonder, 2017                                                Wonder
# ...                                                            ...
# The Mongol King, 2004                              The Mongol King
# Red 11, 2018                                                Red 11
# Return to the Land of Wonders, 2005  Return to the Land of Wonders
# A Plague So Pleasant, 2015                    A Plague So Pleasant
# My Date With Drew, 2005                          My Date With Drew
#
#                                      production_budget  worldwide_gross  year  \
# title_year
# Us, 2019                                      20000000        254210310  2019
# La La Land, 2016                              20000000        426351163  2016
# The Conjuring, 2013                           20000000        318000141  2013
# Bringing Down the House, 2003                 20000000        164675402  2003
# Wonder, 2017                                  20000000        304604712  2017
# ...                                                ...              ...   ...
# The Mongol King, 2004                             7000              900  2004
# Red 11, 2018                                      7000                0  2018
# Return to the Land of Wonders, 2005               5000             1338  2005
# A Plague So Pleasant, 2015                        1400                0  2015
# My Date With Drew, 2005                           1100           181041  2005
#
#                                      gross_budget_ratio
# title_year
# Us, 2019                                      12.710515
# La La Land, 2016                              21.317558
# The Conjuring, 2013                           15.900007
# Bringing Down the House, 2003                  8.233770
# Wonder, 2017                                  15.230236
# ...                                                 ...
# The Mongol King, 2004                          0.128571
# Red 11, 2018                                   0.000000
# Return to the Land of Wonders, 2005            0.267600
# A Plague So Pleasant, 2015                     0.000000
# My Date With Drew, 2005                      164.582727
#
# [2415 rows x 7 columns]

# %%
# Create a new column for gross budget ratio
budgets_df['gross_budget_ratio'] = budgets_df['worldwide_gross'] / budgets_df['production_budget']
budgets_df
# Out:
# /var/folders/m7/tzk7gpbd05j79z_hsb25z6jm0000gn/T/ipykernel_1621/3191329031.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   budgets_df['gross_budget_ratio'] = budgets_df['worldwide_gross'] / budgets_df['production_budget']
#       id release_date                                        title  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5776  77   2004-12-31                              The Mongol King
# 5777  78   2018-12-31                                       Red 11
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#       production_budget  worldwide_gross  year  gross_budget_ratio
# 0             425000000       2776345279  2009            6.532577
# 1             410600000       1045663875  2011            2.546673
# 2             350000000        149762350  2019            0.427892
# 3             330600000       1403013963  2015            4.243841
# 4             317000000       1316721747  2017            4.153696
# ...                 ...              ...   ...                 ...
# 5776               7000              900  2004            0.128571
# 5777               7000                0  2018            0.000000
# 5779               5000             1338  2005            0.267600
# 5780               1400                0  2015            0.000000
# 5781               1100           181041  2005          164.582727
#
# [4387 rows x 7 columns]

# %%
 # Check missing values in key financial columns
missing_values = budgets_df[['production_budget', 'worldwide_gross']].isna().sum()

print("Missing values in budget & revenue columns:")
print(missing_values)
# Out:
# Missing values in budget & revenue columns:
# production_budget    0
# worldwide_gross      0
# dtype: int64

# %%
# Query to count how many titles are identical
same_titles_query = """
SELECT COUNT(*) AS same_titles_count
FROM movie_basics
WHERE primary_title = original_title;
"""
same_titles_count = pd.read_sql(same_titles_query, conn)

# Query to count total rows in movie_basics
total_rows_query = "SELECT COUNT(*) AS total_rows FROM movie_basics;"
total_rows = pd.read_sql(total_rows_query, conn)

# Print the results
print(f"Identical titles: {same_titles_count.iloc[0,0]} / {total_rows.iloc[0,0]}")
# Out:
# Identical titles: 131640 / 146144

# %%
movies_2000s = pd.read_sql("""
select *
from movie_basics
where start_year >= 2000
""", conn)

movies_2000s
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
same_titles = pd.read_sql("""
SELECT COUNT(*) AS same_titles_count
FROM movie_basics
WHERE start_year >= 2000
AND primary_title = original_title;
""", conn)

movies_2000s_total = pd.read_sql("""
SELECT COUNT(*) AS total_rows
FROM movie_basics
WHERE start_year >= 2000;
""", conn)

print(f"Identical titles (2000 & beyond): {same_titles.iloc[0,0]} / {movies_2000s_total.iloc[0,0]}")
# Out:
# Identical titles (2000 & beyond): 131640 / 146144

# %%
# Query to find movies where primary_title and original_title are different
different_titles_query = """
SELECT primary_title, original_title
FROM movie_basics
WHERE primary_title != original_title
LIMIT 20;
"""

different_titles = pd.read_sql(different_titles_query, conn)

print("Sample of different titles:")
print(different_titles)
# Out:
# Sample of different titles:
#                                         primary_title  \
# 0                     One Day Before the Rainy Season
# 1                            The Wandering Soap Opera
# 2                                So Much for Justice!
# 3                        Children of the Green Dragon
# 4                                  The Tragedy of Man
# 5                                       Heaven & Hell
# 6                            Seven Jews from My Class
# 7                Prague: The Restless Heart of Europe
# 8                                   Short Time Heroes
# 9                                             My Land
# 10                         Chatô - The King of Brazil
# 11                                 Burnt by the Sun 2
# 12                                  Asleep in the Sun
# 13                                      Pots and Pans
# 14                                      Mexican Devil
# 15                                             7 Days
# 16                                             Clawed
# 17                                     Party Crashers
# 18  One Step Beyond: The True Story of Géraldine F...
# 19                               Saving Private Perez
#
#                    original_title
# 0                 Ashad Ka Ek Din
# 1           La Telenovela Errante
# 2                  Oda az igazság
# 3        A zöld sárkány gyermekei
# 4             Az ember tragédiája
# 5                  Reverse Heaven
# 6     Siedmiu Zydów z mojej klasy
# 7   Praha - neklidné srdce Evropy
# 8                  Kurzzeithelden
# 9                   Aamaar Bhuvan
# 10         Chatô: O Rei do Brasil
# 11          Utomlennye solntsem 2
# 12                  Dormir al sol
# 13                    Acorralados
# 14               The Devil Inside
# 15          Les 7 jours du talion
# 16                         Sludge
# 17                    Os Penetras
# 18                One Step Beyond
# 19      Salvando al Soldado Pérez

# %%
movies_2000s = movies_2000s.drop(columns=['original_title'])
movies_2000s
# Out:
#          movie_id                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 5 columns]

# %%
# Keep only rows where 'genres' contain Comedy, Drama, or Horror
movies_genres_filtered = movies_2000s[
    movies_2000s['genres'].str.contains("Comedy|Drama|Horror", na=False, regex=True)
]

print(f"Filtered dataset: Now only {len(movies_genres_filtered)} movies remain.")
# Out:
# Filtered dataset: Now only 75296 movies remain.

# %%
test_query = """
select movie_id, person_id, primary_name, count(primary_name) as num_movies
from persons
join (select distinct movie_id, person_id
    from directors d) using(person_id)
group by (person_id)
order by num_movies desc
"""
test_df = pd.read_sql(test_query, conn)
test_df
# Out:
#           movie_id  person_id    primary_name  num_movies
# 0        tt3828760  nm3266654      Omer Pasha          62
# 1       tt10245370  nm3583561     Larry Rosen          51
# 2       tt10288820  nm5592581   Rajiv Chilaka          49
# 3        tt1604891  nm2682776   Stephan Düfel          48
# 4        tt4155970  nm2410514    Graeme Duane          45
# ...            ...        ...             ...         ...
# 109246   tt1733300  nm0000147     Colin Firth           1
# 109247   tt1595655  nm0000136     Johnny Depp           1
# 109248   tt3007512  nm0000128   Russell Crowe           1
# 109249   tt1369706  nm0000118  John Carpenter           1
# 109250   tt0069049  nm0000080    Orson Welles           1
#
# [109251 rows x 4 columns]

# %%
final_query = """
select movie_id, primary_title, start_year, runtime_minutes, genres
from movie_basics
join movie_akas using(movie_id)
join movie_ratings using(movie_id)
where (region = 'US') & (start_year >= 2000)
"""
final_df = pd.read_sql(final_query, conn)

# %%
final_df['start_year'] = final_df['start_year'].astype(str)
final_df['title_year'] = final_df['primary_title'] + ', ' + final_df['start_year']
final_df
# Out:
#         movie_id                       primary_title start_year  \
# 0      tt0069049          The Other Side of the Wind       2018
# 1      tt0112502                             Bigfoot       2017
# 2      tt0159369  Cooper and Hemingway: The True Gen       2013
# 3      tt0192528                       Heaven & Hell       2018
# 4      tt0230212                   The Final Journey       2010
# ...          ...                                 ...        ...
# 30189  tt9822474                     Into the Canyon       2019
# 30190  tt9822474                     Into the Canyon       2019
# 30191  tt9845398                  End of the Century       2019
# 30192  tt9875852                       The House Elf       2019
# 30193  tt9882084                   Chasing Happiness       2019
#
#        runtime_minutes                 genres  \
# 0                122.0                  Drama
# 1                  NaN        Horror,Thriller
# 2                180.0            Documentary
# 3                104.0                  Drama
# 4                120.0                  Drama
# ...                ...                    ...
# 30189             84.0            Documentary
# 30190             84.0            Documentary
# 30191             84.0                  Drama
# 30192             90.0  Comedy,Family,Fantasy
# 30193             96.0            Documentary
#
#                                      title_year
# 0              The Other Side of the Wind, 2018
# 1                                 Bigfoot, 2017
# 2      Cooper and Hemingway: The True Gen, 2013
# 3                           Heaven & Hell, 2018
# 4                       The Final Journey, 2010
# ...                                         ...
# 30189                     Into the Canyon, 2019
# 30190                     Into the Canyon, 2019
# 30191                  End of the Century, 2019
# 30192                       The House Elf, 2019
# 30193                   Chasing Happiness, 2019
#
# [30194 rows x 6 columns]

# %%
final_df.drop_duplicates(keep=False)
# Out:
#         movie_id                       primary_title start_year  \
# 0      tt0069049          The Other Side of the Wind       2018
# 1      tt0112502                             Bigfoot       2017
# 2      tt0159369  Cooper and Hemingway: The True Gen       2013
# 3      tt0192528                       Heaven & Hell       2018
# 4      tt0230212                   The Final Journey       2010
# ...          ...                                 ...        ...
# 30185  tt9783778               Adventures of Aladdin       2019
# 30186  tt9806192                      I Lost My Body       2019
# 30191  tt9845398                  End of the Century       2019
# 30192  tt9875852                       The House Elf       2019
# 30193  tt9882084                   Chasing Happiness       2019
#
#        runtime_minutes                 genres  \
# 0                122.0                  Drama
# 1                  NaN        Horror,Thriller
# 2                180.0            Documentary
# 3                104.0                  Drama
# 4                120.0                  Drama
# ...                ...                    ...
# 30185             87.0      Adventure,Fantasy
# 30186             81.0        Animation,Drama
# 30191             84.0                  Drama
# 30192             90.0  Comedy,Family,Fantasy
# 30193             96.0            Documentary
#
#                                      title_year
# 0              The Other Side of the Wind, 2018
# 1                                 Bigfoot, 2017
# 2      Cooper and Hemingway: The True Gen, 2013
# 3                           Heaven & Hell, 2018
# 4                       The Final Journey, 2010
# ...                                         ...
# 30185               Adventures of Aladdin, 2019
# 30186                      I Lost My Body, 2019
# 30191                  End of the Century, 2019
# 30192                       The House Elf, 2019
# 30193                   Chasing Happiness, 2019
#
# [23923 rows x 6 columns]

# %%
final_df = final_df.set_index('title_year')

# %%
final_df = final_df.drop_duplicates(keep=False)

# %%
pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /opt/anaconda3/lib/python3.12/site-packages (from deep-translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from deep-translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.12.14)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from deep_translator import GoogleTranslator

# %%
final_df = final_df.reset_index()
final_df
# Out:
#                                      title_year   movie_id  \
# 0              The Other Side of the Wind, 2018  tt0069049
# 1                                 Bigfoot, 2017  tt0112502
# 2      Cooper and Hemingway: The True Gen, 2013  tt0159369
# 3                           Heaven & Hell, 2018  tt0192528
# 4                       The Final Journey, 2010  tt0230212
# ...                                         ...        ...
# 23918               Adventures of Aladdin, 2019  tt9783778
# 23919                      I Lost My Body, 2019  tt9806192
# 23920                  End of the Century, 2019  tt9845398
# 23921                       The House Elf, 2019  tt9875852
# 23922                   Chasing Happiness, 2019  tt9882084
#
#                             primary_title start_year  runtime_minutes  \
# 0              The Other Side of the Wind       2018            122.0
# 1                                 Bigfoot       2017              NaN
# 2      Cooper and Hemingway: The True Gen       2013            180.0
# 3                           Heaven & Hell       2018            104.0
# 4                       The Final Journey       2010            120.0
# ...                                   ...        ...              ...
# 23918               Adventures of Aladdin       2019             87.0
# 23919                      I Lost My Body       2019             81.0
# 23920                  End of the Century       2019             84.0
# 23921                       The House Elf       2019             90.0
# 23922                   Chasing Happiness       2019             96.0
#
#                       genres
# 0                      Drama
# 1            Horror,Thriller
# 2                Documentary
# 3                      Drama
# 4                      Drama
# ...                      ...
# 23918      Adventure,Fantasy
# 23919        Animation,Drama
# 23920                  Drama
# 23921  Comedy,Family,Fantasy
# 23922            Documentary
#
# [23923 rows x 6 columns]

# %%
budgets_df = budgets_df.reset_index()
budgets_df
# Out:
#                                title_year  id release_date  \
# 0                                Us, 2019  88   2019-03-22
# 1                        La La Land, 2016  92   2016-12-09
# 2                     The Conjuring, 2013  93   2013-07-19
# 3           Bringing Down the House, 2003  94   2003-03-07
# 4                            Wonder, 2017  95   2017-11-17
# ...                                   ...  ..          ...
# 2410                The Mongol King, 2004  77   2004-12-31
# 2411                         Red 11, 2018  78   2018-12-31
# 2412  Return to the Land of Wonders, 2005  80   2005-07-13
# 2413           A Plague So Pleasant, 2015  81   2015-09-29
# 2414              My Date With Drew, 2005  82   2005-08-05
#
#                               title  production_budget  worldwide_gross  year  \
# 0                                Us           20000000        254210310  2019
# 1                        La La Land           20000000        426351163  2016
# 2                     The Conjuring           20000000        318000141  2013
# 3           Bringing Down the House           20000000        164675402  2003
# 4                            Wonder           20000000        304604712  2017
# ...                             ...                ...              ...   ...
# 2410                The Mongol King               7000              900  2004
# 2411                         Red 11               7000                0  2018
# 2412  Return to the Land of Wonders               5000             1338  2005
# 2413           A Plague So Pleasant               1400                0  2015
# 2414              My Date With Drew               1100           181041  2005
#
#       gross_budget_ratio
# 0              12.710515
# 1              21.317558
# 2              15.900007
# 3               8.233770
# 4              15.230236
# ...                  ...
# 2410            0.128571
# 2411            0.000000
# 2412            0.267600
# 2413            0.000000
# 2414          164.582727
#
# [2415 rows x 8 columns]

# %%
final_df['title_year'] = final_df['title_year'].apply(lambda x: x.strip() if isinstance(x, str) else x)

# %%
import re

# %%
def clean_title_year(text):
    if isinstance(text, str):
        match = re.search(r',\s*\d{4}$', text)
        if match:
            title_part = text[:match.start()]
            year_part = match.group()
        else:
            title_part = text
            year_part = ""
            
        title_part = re.sub(r'[^a-zA-Z0-9\s]', '', title_part)
        return title_part.strip() + year_part
    return text
final_df['title_year'] = final_df['title_year'].apply(clean_title_year)

# %%
def clean_title_year(text):
    if isinstance(text, str):
        match = re.search(r',\s*\d{4}$', text)
        if match:
            title_part = text[:match.start()]
            year_part = match.group()
        else:
            title_part = text
            year_part = ""
            
        title_part = re.sub(r'[^a-zA-Z0-9\s]', '', title_part)
        return title_part.strip() + year_part
    return text
budgets_df['title_year'] = budgets_df['title_year'].apply(clean_title_year)

# %%
final_df = final_df.set_index('title_year')

# %%
final_df = final_df.drop_duplicates(keep=False)

# %%
final_df
# Out:
#                                           movie_id  \
# title_year
# The Other Side of the Wind, 2018         tt0069049
# Bigfoot, 2017                            tt0112502
# Cooper and Hemingway The True Gen, 2013  tt0159369
# Heaven  Hell, 2018                       tt0192528
# The Final Journey, 2010                  tt0230212
# ...                                            ...
# Adventures of Aladdin, 2019              tt9783778
# I Lost My Body, 2019                     tt9806192
# End of the Century, 2019                 tt9845398
# The House Elf, 2019                      tt9875852
# Chasing Happiness, 2019                  tt9882084
#
#                                                               primary_title  \
# title_year
# The Other Side of the Wind, 2018                 The Other Side of the Wind
# Bigfoot, 2017                                                       Bigfoot
# Cooper and Hemingway The True Gen, 2013  Cooper and Hemingway: The True Gen
# Heaven  Hell, 2018                                            Heaven & Hell
# The Final Journey, 2010                                   The Final Journey
# ...                                                                     ...
# Adventures of Aladdin, 2019                           Adventures of Aladdin
# I Lost My Body, 2019                                         I Lost My Body
# End of the Century, 2019                                 End of the Century
# The House Elf, 2019                                           The House Elf
# Chasing Happiness, 2019                                   Chasing Happiness
#
#                                         start_year  runtime_minutes  \
# title_year
# The Other Side of the Wind, 2018              2018            122.0
# Bigfoot, 2017                                 2017              NaN
# Cooper and Hemingway The True Gen, 2013       2013            180.0
# Heaven  Hell, 2018                            2018            104.0
# The Final Journey, 2010                       2010            120.0
# ...                                            ...              ...
# Adventures of Aladdin, 2019                   2019             87.0
# I Lost My Body, 2019                          2019             81.0
# End of the Century, 2019                      2019             84.0
# The House Elf, 2019                           2019             90.0
# Chasing Happiness, 2019                       2019             96.0
#
#                                                         genres
# title_year
# The Other Side of the Wind, 2018                         Drama
# Bigfoot, 2017                                  Horror,Thriller
# Cooper and Hemingway The True Gen, 2013            Documentary
# Heaven  Hell, 2018                                       Drama
# The Final Journey, 2010                                  Drama
# ...                                                        ...
# Adventures of Aladdin, 2019                  Adventure,Fantasy
# I Lost My Body, 2019                           Animation,Drama
# End of the Century, 2019                                 Drama
# The House Elf, 2019                      Comedy,Family,Fantasy
# Chasing Happiness, 2019                            Documentary
#
# [23923 rows x 5 columns]

# %%
budgets_df = budgets_df.set_index('title_year')
budgets_df = budgets_df.drop_duplicates(keep=False)
budgets_df
# Out:
#                                      id release_date  \
# title_year
# Us, 2019                             88   2019-03-22
# La La Land, 2016                     92   2016-12-09
# The Conjuring, 2013                  93   2013-07-19
# Bringing Down the House, 2003        94   2003-03-07
# Wonder, 2017                         95   2017-11-17
# ...                                  ..          ...
# The Mongol King, 2004                77   2004-12-31
# Red 11, 2018                         78   2018-12-31
# Return to the Land of Wonders, 2005  80   2005-07-13
# A Plague So Pleasant, 2015           81   2015-09-29
# My Date With Drew, 2005              82   2005-08-05
#
#                                                              title  \
# title_year
# Us, 2019                                                        Us
# La La Land, 2016                                        La La Land
# The Conjuring, 2013                                  The Conjuring
# Bringing Down the House, 2003              Bringing Down the House
# Wonder, 2017                                                Wonder
# ...                                                            ...
# The Mongol King, 2004                              The Mongol King
# Red 11, 2018                                                Red 11
# Return to the Land of Wonders, 2005  Return to the Land of Wonders
# A Plague So Pleasant, 2015                    A Plague So Pleasant
# My Date With Drew, 2005                          My Date With Drew
#
#                                      production_budget  worldwide_gross  year  \
# title_year
# Us, 2019                                      20000000        254210310  2019
# La La Land, 2016                              20000000        426351163  2016
# The Conjuring, 2013                           20000000        318000141  2013
# Bringing Down the House, 2003                 20000000        164675402  2003
# Wonder, 2017                                  20000000        304604712  2017
# ...                                                ...              ...   ...
# The Mongol King, 2004                             7000              900  2004
# Red 11, 2018                                      7000                0  2018
# Return to the Land of Wonders, 2005               5000             1338  2005
# A Plague So Pleasant, 2015                        1400                0  2015
# My Date With Drew, 2005                           1100           181041  2005
#
#                                      gross_budget_ratio
# title_year
# Us, 2019                                      12.710515
# La La Land, 2016                              21.317558
# The Conjuring, 2013                           15.900007
# Bringing Down the House, 2003                  8.233770
# Wonder, 2017                                  15.230236
# ...                                                 ...
# The Mongol King, 2004                          0.128571
# Red 11, 2018                                   0.000000
# Return to the Land of Wonders, 2005            0.267600
# A Plague So Pleasant, 2015                     0.000000
# My Date With Drew, 2005                      164.582727
#
# [2415 rows x 7 columns]

# %%
finalized_df = final_df.join(budgets_df, on='title_year', how='inner')
master_df = finalized_df[['movie_id', 'primary_title', 'start_year', 'production_budget', 'worldwide_gross', 'gross_budget_ratio', 'genres']]
master_df
# Out:
#                                       movie_id                  primary_title  \
# title_year
# Andersons Cross, 2010                tt0393049               Anderson's Cross
# The Crazies, 2010                    tt0455407                    The Crazies
# House at the End of the Drive, 2014  tt0464054  House at the End of the Drive
# Margaret, 2011                       tt0466893                       Margaret
# Barry Munday, 2010                   tt0482461                   Barry Munday
# ...                                        ...                            ...
# Paul Apostle of Christ, 2018         tt7388562        Paul, Apostle of Christ
# Hereditary, 2018                     tt7784604                     Hereditary
# Blinded by the Light, 2019           tt8266310           Blinded by the Light
# Fahrenheit 119, 2018                 tt8632862                Fahrenheit 11/9
# Unplanned, 2019                      tt9024106                      Unplanned
#
#                                     start_year  production_budget  \
# title_year
# Andersons Cross, 2010                     2010             300000
# The Crazies, 2010                         2010           19000000
# House at the End of the Drive, 2014       2014            1400000
# Margaret, 2011                            2011           14000000
# Barry Munday, 2010                        2010            3000000
# ...                                        ...                ...
# Paul Apostle of Christ, 2018              2018            5000000
# Hereditary, 2018                          2018           10000000
# Blinded by the Light, 2019                2019           15000000
# Fahrenheit 119, 2018                      2018            5000000
# Unplanned, 2019                           2019            6000000
#
#                                      worldwide_gross  gross_budget_ratio  \
# title_year
# Andersons Cross, 2010                              0            0.000000
# The Crazies, 2010                           56445534            2.970818
# House at the End of the Drive, 2014                0            0.000000
# Margaret, 2011                                623292            0.044521
# Barry Munday, 2010                                 0            0.000000
# ...                                              ...                 ...
# Paul Apostle of Christ, 2018                25529498            5.105900
# Hereditary, 2018                            70133905            7.013390
# Blinded by the Light, 2019                         0            0.000000
# Fahrenheit 119, 2018                         6653715            1.330743
# Unplanned, 2019                             18107621            3.017937
#
#                                                         genres
# title_year
# Andersons Cross, 2010                     Comedy,Drama,Romance
# The Crazies, 2010                              Horror,Thriller
# House at the End of the Drive, 2014            Horror,Thriller
# Margaret, 2011                                           Drama
# Barry Munday, 2010                        Comedy,Drama,Romance
# ...                                                        ...
# Paul Apostle of Christ, 2018         Adventure,Biography,Drama
# Hereditary, 2018                          Drama,Horror,Mystery
# Blinded by the Light, 2019              Biography,Comedy,Drama
# Fahrenheit 119, 2018                               Documentary
# Unplanned, 2019                                Biography,Drama
#
# [428 rows x 7 columns]

# %%
genre_series = master_df['genres'].dropna()

# %%
from collections import Counter

all_genres = genre_series.str.split(',').explode().str.strip()
genre_counts = Counter(all_genres)
genre_df = pd.DataFrame(genre_counts.items(), columns=['Genre', 'Count']).sort_values(by='Count', ascending=False)

# %%
genre_df.head(10)
# Out:
#           Genre  Count
# 1         Drama    257
# 0        Comedy    135
# 4      Thriller     79
# 3        Horror     77
# 2       Romance     68
# 7        Action     58
# 5         Crime     48
# 12      Mystery     46
# 9     Biography     38
# 13  Documentary     26

# %%
target_genres = ['Drama', 'Comedy', 'Horror']
filtered_master_df = master_df[master_df['genres'].str.contains('|'.join(target_genres), case=False, na=False)]
filtered_master_df
# Out:
#                                       movie_id                  primary_title  \
# title_year
# Andersons Cross, 2010                tt0393049               Anderson's Cross
# The Crazies, 2010                    tt0455407                    The Crazies
# House at the End of the Drive, 2014  tt0464054  House at the End of the Drive
# Margaret, 2011                       tt0466893                       Margaret
# Barry Munday, 2010                   tt0482461                   Barry Munday
# ...                                        ...                            ...
# Uncle Drew, 2018                     tt7334528                     Uncle Drew
# Paul Apostle of Christ, 2018         tt7388562        Paul, Apostle of Christ
# Hereditary, 2018                     tt7784604                     Hereditary
# Blinded by the Light, 2019           tt8266310           Blinded by the Light
# Unplanned, 2019                      tt9024106                      Unplanned
#
#                                     start_year  production_budget  \
# title_year
# Andersons Cross, 2010                     2010             300000
# The Crazies, 2010                         2010           19000000
# House at the End of the Drive, 2014       2014            1400000
# Margaret, 2011                            2011           14000000
# Barry Munday, 2010                        2010            3000000
# ...                                        ...                ...
# Uncle Drew, 2018                          2018           18000000
# Paul Apostle of Christ, 2018              2018            5000000
# Hereditary, 2018                          2018           10000000
# Blinded by the Light, 2019                2019           15000000
# Unplanned, 2019                           2019            6000000
#
#                                      worldwide_gross  gross_budget_ratio  \
# title_year
# Andersons Cross, 2010                              0            0.000000
# The Crazies, 2010                           56445534            2.970818
# House at the End of the Drive, 2014                0            0.000000
# Margaret, 2011                                623292            0.044521
# Barry Munday, 2010                                 0            0.000000
# ...                                              ...                 ...
# Uncle Drew, 2018                            46527161            2.584842
# Paul Apostle of Christ, 2018                25529498            5.105900
# Hereditary, 2018                            70133905            7.013390
# Blinded by the Light, 2019                         0            0.000000
# Unplanned, 2019                             18107621            3.017937
#
#                                                         genres
# title_year
# Andersons Cross, 2010                     Comedy,Drama,Romance
# The Crazies, 2010                              Horror,Thriller
# House at the End of the Drive, 2014            Horror,Thriller
# Margaret, 2011                                           Drama
# Barry Munday, 2010                        Comedy,Drama,Romance
# ...                                                        ...
# Uncle Drew, 2018                                  Comedy,Sport
# Paul Apostle of Christ, 2018         Adventure,Biography,Drama
# Hereditary, 2018                          Drama,Horror,Mystery
# Blinded by the Light, 2019              Biography,Comedy,Drama
# Unplanned, 2019                                Biography,Drama
#
# [369 rows x 7 columns]

# %%
filtered_master_df['start_year'] = pd.to_numeric(filtered_master_df['start_year'], errors='coerce')

genre_trends = pd.DataFrame()
for genre in ['Drama', 'Comedy', 'Horror']:
    genre_counts = (
        filtered_master_df[filtered_master_df['genres'].str.contains(genre, case=False, na=False)]
        .groupby('start_year')
        .size()
        .reset_index(name=genre)
    )
    if genre_trends.empty:
        genre_trends = genre_counts
    else:
        genre_trends = genre_trends.merge(genre_counts, on='start_year', how='outer')

genre_trends = genre_trends.melt(id_vars=['start_year'], var_name='Genre', value_name='Movie Count')

plt.figure(figsize=(12,6))
sns.lineplot(x='start_year', y='Movie Count', hue='Genre', data=genre_trends, marker='o', linewidth=2)

plt.title('Movie Count Over Time by Genre (Drama, Comedy, Horror)', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Movies', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.grid(True)
plt.legend(title="Genre")

plt.show()
# Out:
# /var/folders/m7/tzk7gpbd05j79z_hsb25z6jm0000gn/T/ipykernel_1621/3158068438.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_master_df['start_year'] = pd.to_numeric(filtered_master_df['start_year'], errors='coerce')

# %%
genre_budget_trends = pd.DataFrame()

for genre in ['Drama', 'Comedy', 'Horror']:
    genre_budget = (
        filtered_master_df[filtered_master_df['genres'].str.contains(genre, case=False, na=False)]
        .groupby('start_year')['production_budget']
        .sum()
        .reset_index(name=genre)
    )
    if genre_budget_trends.empty:
        genre_budget_trends = genre_budget
    else:
        genre_budget_trends = genre_budget_trends.merge(genre_budget, on='start_year', how='outer')

genre_budget_trends = genre_budget_trends.melt(id_vars=['start_year'], var_name='Genre', value_name='Total Budget')

plt.figure(figsize=(12,6))
sns.lineplot(x='start_year', y='Total Budget', hue='Genre', data=genre_budget_trends, marker='o', linewidth=2)

plt.title('Total Production Cost YoY by Genre (Drama, Comedy, Horror)', fontsize=14)
plt.xlabel('Start Year', fontsize=12)
plt.ylabel('Total Production Budget ($)', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.grid(True)
plt.legend(title="Genre")

plt.show()

# %%
print(genre_budget_trends.head(10))  # Show first 10 rows of the budget data
# Out:
#    start_year  Genre  Total Budget
# 0        2010  Drama   184550000.0
# 1        2011  Drama   210845000.0
# 2        2012  Drama   198420000.0
# 3        2013  Drama   172467000.0
# 4        2014  Drama   297745000.0
# 5        2015  Drama   304200000.0
# 6        2016  Drama   269000000.0
# 7        2017  Drama   240227000.0
# 8        2018  Drama   193850000.0
# 9        2019  Drama    36000000.0

# %%
genre_financials = pd.DataFrame()

for genre in ['Horror']:
    genre_data = (
        filtered_master_df[filtered_master_df['genres'].str.contains(genre, case=False, na=False)]
        .groupby('start_year')[['production_budget', 'worldwide_gross']]
        .sum()
        .reset_index()
    )
    genre_data['Genre'] = genre
    genre_financials = pd.concat([genre_financials, genre_data], ignore_index=True)

genre_financials = genre_financials.melt(id_vars=['start_year', 'Genre'], 
                                         var_name='Metric', value_name='Amount')

genre_financials['Amount'] = genre_financials['Amount'] / 100_000_000

plt.figure(figsize=(14, 7))
sns.lineplot(x='start_year', y='Amount', hue='Metric', data=genre_financials, 
             marker='o', linewidth=2)

plt.title('Production Budget vs. Worldwide Gross YoY (Horror)', fontsize=14)
plt.xlabel('Start Year', fontsize=12)
plt.ylabel('Dollar Amount (Hundreds of Millions)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title="Metric")  # Ensure legend clearly differentiates Budget vs Gross

plt.show()

# %%
genre_avg_financials = pd.DataFrame()

for genre in ['Horror']:
    genre_data = (
        filtered_master_df[filtered_master_df['genres'].str.contains(genre, case=False, na=False)]
        .groupby('start_year')[['production_budget', 'worldwide_gross']]
        .mean()
        .reset_index()
    )
    genre_data['Genre'] = genre  # Add genre as a column
    genre_avg_financials = pd.concat([genre_avg_financials, genre_data], ignore_index=True)

genre_avg_financials = genre_avg_financials.melt(id_vars=['start_year', 'Genre'], 
                                                 var_name='Metric', value_name='Amount')

genre_avg_financials['Amount'] = genre_avg_financials['Amount'] / 1_000_000

plt.figure(figsize=(14, 7))
sns.barplot(x='start_year', y='Amount', hue='Metric', data=genre_avg_financials, 
            ci=None, palette=['#1f77b4', '#ff7f0e'])

plt.title('Average Production Budget vs. Average Gross YoY (Horror)', fontsize=14)
plt.xlabel('Start Year', fontsize=12)
plt.ylabel('Amount ($ Millions)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Metric")
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# /var/folders/m7/tzk7gpbd05j79z_hsb25z6jm0000gn/T/ipykernel_1621/3660383155.py:19: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='start_year', y='Amount', hue='Metric', data=genre_avg_financials,

# %%
genre_roi_trends = pd.DataFrame()

for genre in ['Drama', 'Comedy', 'Horror']:
    genre_data = (
        filtered_master_df[filtered_master_df['genres'].str.contains(genre, case=False, na=False)]
        .groupby('start_year')['gross_budget_ratio']
        .mean()
        .reset_index()
    )
    genre_data['Genre'] = genre
    genre_roi_trends = pd.concat([genre_roi_trends, genre_data], ignore_index=True)

genre_roi_trends = genre_roi_trends.melt(id_vars=['start_year', 'Genre'], 
                                         var_name='Metric', value_name='ROI')

custom_palette = sns.color_palette("viridis", as_cmap=True)

plt.figure(figsize=(14, 7))
sns.lineplot(x='start_year', y='ROI', hue='Genre', data=genre_roi_trends, 
             marker='o', linewidth=2, palette="viridis")


plt.title('Average Return on Investment YoY by Genre', fontsize=14)
plt.xlabel('Start Year', fontsize=12)
plt.ylabel('ROI (Gross-to-Budget Ratio)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(title="Genre")

plt.show()

# %%
horror_roi = (
    filtered_master_df[filtered_master_df['genres'].str.contains('Horror', case=False, na=False)]
    .groupby('start_year')['gross_budget_ratio']
    .sum()
    .reset_index()
)

plt.figure(figsize=(14, 7))
sns.barplot(x='start_year', y='gross_budget_ratio', data=horror_roi, 
            palette="magma")  # Keep the same vibrant color scheme

plt.title('Total Return on Investment YoY (Horror)', fontsize=14)
plt.xlabel('Start Year', fontsize=12)
plt.ylabel('Total ROI (Gross-to-Budget Ratio)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# /var/folders/m7/tzk7gpbd05j79z_hsb25z6jm0000gn/T/ipykernel_1621/1934315329.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='start_year', y='gross_budget_ratio', data=horror_roi,
